# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('HR_comma_sep.csv')
df.head()
df.dropna()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
y  = df.groupby('left')['left'].agg('count')
x = np.array([0,1])

# %%
dummy1 = pd.get_dummies(df['salary'])
df= pd.concat([df,dummy1],axis='columns')

# %%
df = df.drop(['last_evaluation','Department', 'promotion_last_5years','salary','average_montly_hours','Work_accident'], axis='columns')

# %%
df
# Out:
#        satisfaction_level  number_project  time_spend_company  left  high  \
# 0                    0.38               2                   3     1     0
# 1                    0.80               5                   6     1     0
# 2                    0.11               7                   4     1     0
# 3                    0.72               5                   5     1     0
# 4                    0.37               2                   3     1     0
# ...                   ...             ...                 ...   ...   ...
# 14994                0.40               2                   3     1     0
# 14995                0.37               2                   3     1     0
# 14996                0.37               2                   3     1     0
# 14997                0.11               6                   4     1     0
# 14998                0.37               2                   3     1     0
#
#        low  medium
# 0        1       0
# 1        0       1
# ...

# %%
condition1  = df['satisfaction_level'] > 0.7 
condition2 = df['left'] == 1

# %%
df = df[~(condition1 & condition2)]
df
# Out:
#        satisfaction_level  number_project  time_spend_company  left  high  \
# 0                    0.38               2                   3     1     0
# 2                    0.11               7                   4     1     0
# 4                    0.37               2                   3     1     0
# 5                    0.41               2                   3     1     0
# 6                    0.10               6                   4     1     0
# ...                   ...             ...                 ...   ...   ...
# 14994                0.40               2                   3     1     0
# 14995                0.37               2                   3     1     0
# 14996                0.37               2                   3     1     0
# 14997                0.11               6                   4     1     0
# 14998                0.37               2                   3     1     0
#
#        low  medium
# 0        1       0
# 2        0       1
# ...

# %%
condition3  = df['satisfaction_level'] < 0.3 
condition4 = df['left'] == 0
df = df[~(condition3 & condition4)]
df[df['left']==0]
# Out:
#        satisfaction_level  number_project  time_spend_company  left  high  \
# 2000                 0.58               4                   3     0     0
# 2001                 0.82               2                   3     0     0
# 2002                 0.45               5                   3     0     0
# 2003                 0.78               5                   3     0     0
# 2004                 0.49               3                   2     0     0
# ...                   ...             ...                 ...   ...   ...
# 14206                0.90               3                  10     0     1
# 14207                0.74               5                  10     0     1
# 14208                0.85               3                  10     0     1
# 14209                0.33               3                  10     0     1
# 14210                0.50               4                   3     0     0
#
#        low  medium
# 2000     1       0
# 2001     1       0
# ...

# %%
X = df.drop(['left'],axis ='columns')
y= df['left']
    
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, )

from sklearn.linear_model import LogisticRegression
reg_model = LogisticRegression()

reg_model.fit(X_train ,y_train)
reg_model.score(X_train ,y_train)
# Out:
# 0.9541336893296463

# %%
# Out:
# /Users/dawoodzargar/anaconda3/lib/python3.10/site-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 0
